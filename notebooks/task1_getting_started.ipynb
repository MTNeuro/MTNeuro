# %% [markdown]
# # Getting Started: Region-Level Classification (Task 1)

# %% [markdown]
# ### Install the required packages

# %%
#Download and install Pytorch for CUDA 10.2
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu102
#Download and install Pytorch for CUDA 11.3
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu113
    
# !pip install intern
# !pip install scikit-learn
# !pip install timm
# !pip install pretrainedmodels
# !pip install efficientnet_pytorch

#setting up the segmentation_models.pytorch library
# !pip install github-clone
# !ghclone https://github.com/qubvel/segmentation_models.pytorch/tree/master/segmentation_models_pytorch 
# !cp -rf segmentation_models_pytorch ../MTNeuro/.
# !rm -rf segmentation_models_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu102
# Requirement already satisfied: torch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (1.11.0+cu102)
# Requirement already satisfied: torchvision in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (0.12.0+cu102)
# Requirement already satisfied: typing-extensions in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torch) (4.1.1)
# Requirement already satisfied: requests in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (9.1.1)
# Requirement already satisfied: numpy in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (3.3)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (1.11.0+cu102)
# Requirement already satisfied: torchvision in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (0.12.0+cu102)
# Requirement already satisfied: typing-extensions in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torch) (4.1.1)
# Requirement already satisfied: numpy in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision) (9.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: intern in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: nose2 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (0.11.0)
# Requirement already satisfied: numpy in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (1.21.5)
# Requirement already satisfied: mock in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (4.0.3)
# Requirement already satisfied: zmesh in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (1.4.2)
# Requirement already satisfied: requests>=2.11.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (2.27.1)
# Requirement already satisfied: six in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (1.16.0)
# Requirement already satisfied: blosc>=1.4.4 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from intern) (1.10.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.11.1->intern) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.11.1->intern) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.11.1->intern) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.11.1->intern) (1.26.9)
# Requirement already satisfied: coverage>=4.4.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from nose2->intern) (6.4.1)
# Requirement already satisfied: scikit-learn in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from scikit-learn) (1.8.1)
# Requirement already satisfied: timm in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: torch>=1.4 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from timm) (1.11.0+cu102)
# Requirement already satisfied: torchvision in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from timm) (0.12.0+cu102)
# Requirement already satisfied: typing-extensions in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: requests in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->timm) (2.27.1)
# Requirement already satisfied: numpy in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->timm) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->timm) (9.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->timm) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->timm) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->timm) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->timm) (2020.6.20)
# Requirement already satisfied: pretrainedmodels in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (0.7.4)
# Requirement already satisfied: tqdm in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from pretrainedmodels) (4.64.0)
# Requirement already satisfied: torchvision in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from pretrainedmodels) (0.12.0+cu102)
# Requirement already satisfied: munch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from pretrainedmodels) (2.5.0)
# Requirement already satisfied: torch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from pretrainedmodels) (1.11.0+cu102)
# Requirement already satisfied: six in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from munch->pretrainedmodels) (1.16.0)
# Requirement already satisfied: typing-extensions in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torch->pretrainedmodels) (4.1.1)
# Requirement already satisfied: requests in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->pretrainedmodels) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->pretrainedmodels) (9.1.1)
# Requirement already satisfied: numpy in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torchvision->pretrainedmodels) (1.21.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->pretrainedmodels) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->pretrainedmodels) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->pretrainedmodels) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests->torchvision->pretrainedmodels) (3.3)
# Requirement already satisfied: efficientnet_pytorch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: torch in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from efficientnet_pytorch) (1.11.0+cu102)
# Requirement already satisfied: typing-extensions in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (4.1.1)
# Requirement already satisfied: github-clone in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from github-clone) (0.6.2)
# Requirement already satisfied: requests>=2.20.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from github-clone) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.20.0->github-clone) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.20.0->github-clone) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.20.0->github-clone) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /home/lsathidevi3/miniconda3/lib/python3.10/site-packages (from requests>=2.20.0->github-clone) (3.3)
# Cloning into 'segmentation_models_pytorch'...
# done.

# %% [markdown]
# ### Importing required packages

# %%
#import libraries and set random seed
import sys
import matplotlib.pyplot as plt
import numpy as np
import json as json
from tqdm import tqdm

#pytorch imports
import torch
from torchvision import transforms
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid

sys.path.append('../MTNeuro/')                 #setting the location to look for the required packages
#BossDB library and MTNeuro dataset loader
from intern import array
from bossdbdataset import BossDBDataset               

from trainer import Trainer                    #trainer function used to train the models
import MTNeuro.models

from sklearn.metrics import confusion_matrix

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Loading the Configurations for training a Pytorch Classifier

# %% [markdown]
# Resnet-18 architecture is used as an example model for demonstrating data access and supervised training

# %%
##load the task config for 2D 4-class setting that specifies the x,y ranges to pick from the data for forming the slices
task_config = json.load(open('../MTNeuro/taskconfig/task1.json'))

##Load the network config for the 2D model for 4-class setting, with the batch size and model config information
network_config = json.load(open('../MTNeuro/networkconfig/SUP_ResNet-18_2D.json'))

# %% [markdown]
# ## Load the Data using the BossDB dataloader

# %%
####Specify the required transforms and load the data for task 2

##if no transformations are preferred for the data
transform = transforms.Compose([transforms.ToTensor(),])

##Set-up the train dataloader and validation dataloader
train_data =  BossDBDataset(task_config, None, 'train', image_transform = transform, mask_transform = transform)
val_data = BossDBDataset(task_config, None, 'val', image_transform = transform, mask_transform = transform)

train_dataloader = DataLoader(dataset=train_data,
                                        batch_size=network_config['batch_size'],
                                        shuffle=True)
validation_dataloader = DataLoader(dataset=val_data,
                                        batch_size=network_config['batch_size'],
                                        shuffle=True)

# %%
#access the input and the groundtruth of first batch
x,y = next(iter(train_dataloader))

#shape of the batch
print(f'x = shape: {x.shape}; type: {x.dtype}')
print(f'x = min: {x.min()}; max: {x.max()}')
print(f'y = shape: {y.shape}; classes: {y.unique()}; type: {y.dtype}')
print(f'y = min: {y.min()}; max: {y.max()}')
# Out:
# x = shape: torch.Size([8, 1, 256, 256]); type: torch.float32
# x = min: 0.0; max: 1.0
# y = shape: torch.Size([8]); classes: tensor([0, 1, 2]); type: torch.int64
# y = min: 0; max: 2

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# ### Visualize the a slice from the first batch and its groundtruth annotation

# %%
plt.imshow(x.squeeze()[0], cmap='gray')
print('Region class:' + str(y.squeeze()[0]))
# Out:
# Region class:tensor(0)

# %% [markdown]
# ### Create a collage of random slices from the training data

# %%
import random

#reshape data and select a random subset of 100 slices
reshaped_data = [data[0][0] for data in train_data]
random_samples_from_data = random.sample(reshaped_data,100)
    
grid_img = make_grid(torch.stack(random_samples_from_data).unsqueeze(1), nrow=10)
plt.figure(figsize=(14,14))
plt.imshow(grid_img[0], cmap='gray')

# %% [markdown]
# ## Load the model

# %%
## Specify the device to run the model on
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

## Load the model with the configuration specifiedd through UNet_2D.json
print('loading ResNet18 model')
model = MTNeuro.models.resnet_xray_classifier(
                resnet_model = 'resnet18',
                depth=network_config['in_channels'],
                num_classes=network_config['classes'],
                ).to(device)
print('Done loading the model')
# Out:
# loading ResNet18 model
# Done loading the model

# %% [markdown]
# ## Set the Loss criteria and the Optimizer

# %%
# criterion
criterion = torch.nn.CrossEntropyLoss()

# optimizer (picks the required information from the network config file UNet_2D.json)
if network_config["optimizer"] == "SGD":
    optimizer = torch.optim.SGD(model.parameters(), lr=network_config["learning_rate"])
if network_config["optimizer"] == "Adam":
    optimizer = torch.optim.Adam(model.parameters(), lr=network_config["learning_rate"], betas=(network_config["beta1"],network_config["beta2"]))

# %% [markdown]
# ## Train the model

# %%
###Configure the trainer
trainer = Trainer(model=model,
                    device=device,
                    criterion=criterion,
                    optimizer=optimizer,
                    training_DataLoader=train_dataloader,
                    validation_DataLoader=validation_dataloader,
                    lr_scheduler=None,
                    epochs=network_config["epochs"],
                    epoch=0,
                    notebook=True)

# start training
training_losses, validation_losses, lr_rates = trainer.run_trainer()
# Out:
# Progress:   0%|          | 0/1 [00:00<?, ?it/s]
# Training:   0%|          | 0/135 [00:00<?, ?it/s]
# Validation:   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ### Evaluate the model

# %%
#function to predict using trained model
def predict(img, model, device):
        model.eval()
        x = img.to(device)            #send input to device
        with torch.no_grad():
            out = model(x)            #model forward pass

        out_argmax = torch.argmax(out, dim=1)  #perform softmax on outputs
        return out_argmax

# %%
#take and save the predictions and corresponding metrics
#load the test data
test_data =  BossDBDataset(task_config, None, "test", image_transform = transform, mask_transform = transform)
test_dataloader = DataLoader(dataset=test_data,
                                        batch_size=network_config['batch_size'],
                                        shuffle=False)
 
batch_iter = tqdm(enumerate(test_dataloader), 'test', total=len(test_dataloader), leave=False)
num_classes = network_config['classes']
correct = 0
total = 0
confusion = torch.zeros(num_classes,num_classes)

for i, (x, y) in batch_iter:
    label = y.to(device) #can do this on CPU
    with torch.no_grad():
        pred_class = predict(x, model, device)
        correct += pred_class.eq(label.view_as(pred_class)).sum().item()
        total += len(label)
        confusion += confusion_matrix(label.cpu(), pred_class.cpu(), labels=[0,1,2,3])
acc = correct/total
confusion = confusion.detach().cpu().numpy()
print('Accuracy: {}'.format(acc))
print('Confusion Matrix: ')
print(confusion)
# Out:
# Accuracy: 0.85
# Confusion Matrix:
# [[50. 10. 10. 10.]
#  [ 0. 40.  0.  0.]
#  [ 0.  0. 40.  0.]
#  [ 0.  0.  0. 40.]]
